# %%
import os
import numpy as np
import shutil
import pandas as pd

train_ratio = 0.9
root_dir = 'Data'
classes = ['Acne', 'Eczema', 'Lichen Planus']

train_df = pd.DataFrame(columns=['Disease', 'Label'])
test_df = pd.DataFrame(columns=['Disease'])

# create empty folders that will hold all training and testing images
if not os.path.exists(root_dir + '/train/train_images'):
    os.makedirs(root_dir + '/train/train_images')
    os.makedirs(root_dir + '/test/test_images')


for item in classes:
    # collect all filenames from the indivisual folders
    src = root_dir +'/'+ item
    all_filenames = os.listdir(src)
    np.random.shuffle(all_filenames) 
    
    # split the list of filenames into train and test filenames
    train_filenames, test_filenames = np.split(np.array(all_filenames),
                                               [int(len(all_filenames)* (train_ratio))])
    
    # create a dataframe of the filenames and their labels
    df_train = pd.DataFrame(train_filenames, columns=['Disease'])
    df_train['Label'] = item
    
    
    df_test = pd.DataFrame(test_filenames, columns=['Disease'])
    df_test['Label'] = item
    
    train_df = train_df.append(df_train, ignore_index=True)
    test_df =test_df.append(df_test, ignore_index=True)
    
    train_filenames = [src+'/'+ name for name in train_filenames.tolist()]
    test_filenames = [src+'/' + name for name in test_filenames.tolist()]

    for name in train_filenames:
        shutil.copy(name, 'Data/train/train_images')

    for name in test_filenames:
        shutil.copy(name, 'Data/test/test_images')

    print('Training: ', len(train_filenames))
    print('Testing: ', len(test_filenames))
# Out:
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/pandas/core/frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# Training:  355
# Testing:  40
# Training:  278
# Testing:  31
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-4d1de096d082> in <module>
#      20     # collect all filenames from the indivisual folders
#      21     src = root_dir +'/'+ item
# ---> 22     all_filenames = os.listdir(src)
#      23     np.random.shuffle(all_filenames)
#      24
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data/Lichen Planus'

# %%
test_df
# Out:
#                              Disease          Label
# 0             acne-excoriated-10.jpg           Acne
# 1                 acne-cystic-65.jpg           Acne
# 2                 acne-cystic-85.jpg           Acne
# 3        acne-open-comedo-73 (1).jpg           Acne
# 4                 acne-cystic-39.jpg           Acne
# 5                 acne-cystic-91.jpg           Acne
# 6               acne-pustular-29.jpg           Acne
# 7             acne-excoriated-21.jpg           Acne
# 8          acne-closed-comedo-13.jpg           Acne
# 9                 acne-cystic-15.jpg           Acne
# 10                acne-cystic-54.jpg           Acne
# 11                acne-cystic-44.jpg           Acne
# 12                acne-cystic-34.jpg           Acne
# 13              acne-pustular-72.jpg           Acne
# 14            acne-open-comedo-7.jpg           Acne
# 15                acne-cystic-90.jpg           Acne
# 16        acne-open-comedo-9 (1).jpg           Acne
# 17              acne-pustular-23.jpg           Acne
# 18                acne-cystic-67.jpg           Acne
# 19            acne-excoriated-11.jpg           Acne
# 20                acne-cystic-68.jpg           Acne
# 21                acne-cystic-49.jpg           Acne
# 22                 acne-cystic-9.jpg           Acne
# 23              acne-pustular-73.jpg           Acne
# 24         acne-closed-comedo-10.jpg           Acne
# 25         acne-closed-comedo-25.jpg           Acne
# 26              acne-pustular-22.jpg           Acne
# 27           acne-open-comedo-11.jpg           Acne
# 28         acne-closed-comedo-22.jpg           Acne
# 29         acne-closed-comedo-17.jpg           Acne
# ..                               ...            ...
# 81             lichen-planus-224.jpg  Lichen Planus
# 82          Lichen-Planus-Drug-3.jpg  Lichen Planus
# 83              lichen-planus-86.jpg  Lichen Planus
# 84              lichen-planus-23.jpg  Lichen Planus
# 85   08lichenPlanusTongue1122051.jpg  Lichen Planus
# 86             lichen-planus-240.jpg  Lichen Planus
# 87          Lichen-Planus-Oral-9.jpg  Lichen Planus
# 88             lichen-planus-207.jpg  Lichen Planus
# 89              lichen-planus-41.jpg  Lichen Planus
# 90         Lichen-Planus-Oral-20.jpg  Lichen Planus
# 91             lichen-planus-252.jpg  Lichen Planus
# 92         Lichen-Planus-Drug-19.jpg  Lichen Planus
# 93             lichen-planus-175.jpg  Lichen Planus
# 94              lichen-planus-36.jpg  Lichen Planus
# 95             Lichen-planus-304.jpg  Lichen Planus
# 96         Lichen-Planus-Oral-24.jpg  Lichen Planus
# 97             lichen-planus-263.jpg  Lichen Planus
# 98        Lichen-Planus-Penis-13.jpg  Lichen Planus
# 99              lichen-planus-66.jpg  Lichen Planus
# 100             lichen-planus-12.jpg  Lichen Planus
# 101             lichen-planus-42.jpg  Lichen Planus
# 102             lichen-planus-84.jpg  Lichen Planus
# 103            lichen-planus-178.jpg  Lichen Planus
# 104   Lichen-Planus-Palm-Soles-9.jpg  Lichen Planus
# 105            lichen-planus-281.jpg  Lichen Planus
# 106            lichen-planus-246.jpg  Lichen Planus
# 107             lichen-planus-49.jpg  Lichen Planus
# 108              8Psoriasis2-219.jpg  Lichen Planus
# 109             lichen-planus-70.jpg  Lichen Planus
# 110            lichen-planus-137.jpg  Lichen Planus
#
# [111 rows x 2 columns]

# %%
# converting to csv
train_df.to_csv('Data/train/train_data.csv', index=False)
test_df.to_csv('Data/test/test_data.csv', index=False)
